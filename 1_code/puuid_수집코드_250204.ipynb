# %%
import requests
import time
import csv
import os
import pandas as pd

# %% [markdown]
# ## Config (API_KEY 입력 필요함)

# %%
# 설정
API_KEY = "본인 API KEY 직접 입력"
HEADERS = {"X-Riot-Token": API_KEY}

# 협곡 솔랭만 검색
TIERS = ["IRON", "BRONZE", "SILVER", "GOLD", "PLATINUM", "EMERALD", "DIAMOND"]
DIVISIONS = ["I", "II", "III", "IV"]
QUEUE = "RANKED_SOLO_5x5"

# 플랫폼 & 호스트
platform_host = {
    "KR":"kr.api.riotgames.com",
    "BR1":"br1.api.riotgames.com",
	"EUN1":"eun1.api.riotgames.com",
	"EUW1":"euw1.api.riotgames.com",
	"JP1":"jp1.api.riotgames.com",
	"LA1":"la1.api.riotgames.com",
	"LA2":"la2.api.riotgames.com",
    "ME1":"me1.api.riotgames.com",
	"NA1":"na1.api.riotgames.com",
	"OC1":"oc1.api.riotgames.com",
	"RU":"ru.api.riotgames.com",
	"SG2":"sg2.api.riotgames.com",
    "TR1":"tr1.api.riotgames.com",
	"TW2":"tw2.api.riotgames.com",
	"VN2":"vn2.api.riotgames.com"
}

# %% [markdown]
# ## 메인

# %% [markdown]
# - 데이터 저장 & 수집 함수 (아이언 ~ 다이아)
# - 티어, 디비젼, puuid만 저장함
# - 다른 정보도 필요하면 수정해야함

# %%
def save_to_csv(data_list, filename):
    """수집된 PUUID 리스트를 CSV 파일에 이어씁니다."""
    if not data_list:
        return
        
    file_exists = os.path.isfile(filename)
    
    with open(filename, mode='a', encoding='utf-8', newline='') as f:
        writer = csv.writer(f)
        # 파일이 처음 생성될 때만 헤더 작성
        if not file_exists:
            writer.writerow(['tier', 'division', 'puuid', 'leagueId', 'leaguePoints', 'wins', 'losses', 'hotStreak', 'veteran', 'freshBlood', 'inactive'])
        
        for row in data_list:
            writer.writerow(row)
    print(f"  -> {len(data_list)}개 데이터 저장 완료.")

def collect_all_data(platform):
    """모든 티어, 디비전을 순회하는 메인 함수.
    platform은 platform_host의 key 입력"""
    
    BASE_URL = f"https://{platform}.api.riotgames.com"
    OUTPUT_FILE = f"data/01_puuids/{platform}_puuids_iron_diamond.csv"
    total_count = 0
    
    for tier in TIERS:
        for division in DIVISIONS:
            print(f"\n===== 시작: {tier} {division} =====")
            page = 1
            
            while True:
                try:
                    # API req
                    url = f"{BASE_URL}/lol/league/v4/entries/{QUEUE}/{tier}/{division}?page={page}&api_key={API_KEY}"
                    response = requests.get(url, headers=HEADERS)
                    
                    # 에러 처리
                    if response.status_code != 200:
                        print(f"Warning: {response.status_code} 에러 발생. 5초 대기 후 리트.")
                        time.sleep(5)
                        continue
                    
                    entries = response.json()
                    
                    # 더 이상 데이터가 없으면 다음 Division으로 넘어감
                    if not entries:
                        print(f"  -> {page}페이지 결과 없음. {tier} {division} 종료.")
                        break
                    
                    # 데이터 파싱
                    current_batch = []
                    for entry in entries:
                        # name = entry.get('summonerName', 'Unknown')
                        puuid = entry.get('puuid')
                        leagueid = entry.get('leagueId')
                        leaguepoints = entry.get('leaguePoints')
                        wins = entry.get('wins')
                        losses = entry.get('losses')
                        hotstreak = entry.get('hotStreak')
                        veteran = entry.get('veteran')
                        freshblood = entry.get('freshBlood')
                        inactive = entry.get('inactive')
                        
                        if puuid:
                            current_batch.append([tier, division, puuid, leagueid, leaguepoints, wins, losses, hotstreak, veteran, freshblood, inactive])
                    
                    # 파일 저장 (batch 단위)
                    save_to_csv(current_batch, OUTPUT_FILE)
                    total_count += len(current_batch)
                    
                    print(f"  [{tier} {division}] {page}페이지 수집 완료 ({len(current_batch)}명)")
                    
                    # 다음 페이지로
                    page += 1
                    
                    # Rate Limit 방지 (개발자 키: 1초당 20회 / 2분당 100회)
                    # 안전하게 1.2초 대기. 120초 100회 맞추려고
                    # time.sleep(1.2)

                    # Rate Limits for Personal Key : 50 requests every 10 seconds
                    time.sleep(0.3)
                    
                except Exception as e:
                    print(f"오류 발생: {e}")
                    time.sleep(5)
                    # 오류 발생 시 break
                    break

    print(f"\n{platform}서버. {total_count}명의 PUUID가 저장되었습니다.")

# %% [markdown]
# - 데이터 저장 & 수집 함수 (마, 그마, 챌)

# %%
def collect_high_tier_data(platform):
    """
    마스터, 그랜드마스터, 챌린저 데이터를 모두 수집, 하나의 CSV에 저장
    """
    LEAGUES = ['masterleagues','grandmasterleagues','challengerleagues']
    OUTPUT_FILE = f"data/01_puuids/{platform}_puuids_high_tiers.csv"
    
    # 반복문 시작 전에 파일 open(mode='w'로 초기화)
    with open(OUTPUT_FILE, mode='w', encoding='utf-8', newline='') as f:
        writer = csv.writer(f)
        
        # 헤더
        writer.writerow(['tier', 'puuid', 'leaguePoints', 'wins', 'losses', 'hotStreak', 'veteran', 'freshBlood', 'inactive'])
        
        # 파일이 열린 상태로 순회
        for league in LEAGUES:
            queue = "RANKED_SOLO_5x5"
            BASE_URL = f"https://{platform}.api.riotgames.com"
            
            url = f"{BASE_URL}/lol/league/v4/{league}/by-queue/{queue}?api_key={API_KEY}"
            
            print(f"--- {league} 데이터 요청 중... ---")
            
            try:
                response = requests.get(url, headers=HEADERS)
                
                if response.status_code != 200:
                    print(f"  -> API 호출 실패! 코드: {response.status_code}")
                    continue
    
                data = response.json()
                
                tier = data.get('tier')
                entries = data.get('entries', [])
                
                print(f"  -> {tier} 응답 완료. {len(entries)}명 저장 시작.")
                
                # 열려있는 파일(f)에 데이터를 이어 씀
                count = 0
                for entry in entries:
                    """여기는 디비젼 구분 없음"""
                    puuid = entry.get('puuid')
                    leaguepoints = entry.get('leaguePoints')
                    wins = entry.get('wins')
                    losses = entry.get('losses')
                    hotstreak = entry.get('hotStreak')
                    veteran = entry.get('veteran')
                    freshblood = entry.get('freshBlood')
                    inactive = entry.get('inactive')
                    # PUUID가 있는 경우에만 저장
                    if puuid: 
                        writer.writerow([tier, puuid, leaguepoints, wins, losses, hotstreak, veteran, freshblood, inactive])
                        count += 1
                
                print(f"  -> {count}명 저장 완료.")
                
                # 안전하게 다음 요청 전 대기
                time.sleep(1)

            except Exception as e:
                print(f"오류 발생 ({league}): {e}")

    print(f"\n작업 완료. {platform}서버. 파일명: {OUTPUT_FILE}")

# %% [markdown]
# ## EXECUTE

# %%
platforms = [k.lower() for k in platform_host.keys()]

# %%
for platform in platforms:
    collect_all_data(platform)
# Out:
# ===== 시작: IRON I =====
#   -> 205개 데이터 저장 완료.
#   [IRON I] 1페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 2페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 3페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 4페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 5페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 6페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 7페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 8페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 9페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 10페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 11페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 12페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 13페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 14페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 15페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 16페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 17페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 18페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 19페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 20페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 21페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 22페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 23페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 24페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 25페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 26페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 27페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 28페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 29페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 30페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IRON I] 31페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [IR
이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 150페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 151페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 152페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 153페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 154페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 155페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 156페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 157페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 158페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 159페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 160페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 161페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 162페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [SILVER II] 163페이지 수집 완료 (205명)
# ...
#   [EMERALD I] 15페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 16페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 17페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 18페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 19페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 20페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 21페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 22페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 23페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 24페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD I] 25페이지 수집 완료 (205명)
#   -> 52개 데이터 저장 완료.
#   [EMERALD I] 26페이지 수집 완료 (52명)
#   -> 27페이지 결과 없음. EMERALD I 종료.
#
# ===== 시작: EMERALD II =====
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 1페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 2페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 3페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 4페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 5페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 6페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 7페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 8페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 9페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 10페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 11페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 12페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 13페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 14페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 15페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 16페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 17페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 18페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 19페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 20페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 21페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 22페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 23페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 24페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 25페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 26페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 27페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 28페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 29페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 30페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 31페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 32페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 33페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 34페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 35페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 36페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 37페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD II] 38페이지 수집 완료 (205명)
#   -> 91개 데이터 저장 완료.
#   [EMERALD II] 39페이지 수집 완료 (91명)
#   -> 40페이지 결과 없음. EMERALD II 종료.
#
# ===== 시작: EMERALD III =====
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 1페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 2페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 3페이지 수집 완료 (205명)
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 4페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 5페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 6페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 7페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 8페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 9페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 10페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 11페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 12페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 13페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 14페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 15페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 16페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 17페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 18페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 19페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 20페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 21페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 22페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 23페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 24페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 25페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 26페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 27페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 28페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 29페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 30페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 31페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 32페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 33페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 34페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 35페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 36페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 37페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 38페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 39페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 40페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 41페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 42페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 43페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 44페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 45페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 46페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 47페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 48페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD III] 49페이지 수집 완료 (205명)
#   -> 94개 데이터 저장 완료.
#   [EMERALD III] 50페이지 수집 완료 (94명)
#   -> 51페이지 결과 없음. EMERALD III 종료.
#
# ===== 시작: EMERALD IV =====
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 1페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 2페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 3페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 4페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 5페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 6페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 7페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 8페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 9페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 10페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 11페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 12페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 13페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 14페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 15페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 16페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 17페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 18페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 19페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 20페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 21페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 22페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 23페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 24페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 25페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 26페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 27페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 28페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 29페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 30페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 31페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 32페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 33페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 34페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 35페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 36페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 37페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 38페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 39페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 40페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 41페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 42페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 43페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 44페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 45페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 46페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 47페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 48페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 49페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 50페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 51페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 52페이지 수집 완료 (205명)
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 53페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 54페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 55페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 56페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 57페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 58페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 59페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 60페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 61페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 62페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 63페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 64페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 65페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 66페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 67페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 68페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 69페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 70페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 71페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 72페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 73페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 74페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 75페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 76페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 77페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 78페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 79페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 80페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [EMERALD IV] 81페이지 수집 완료 (205명)
#   -> 66개 데이터 저장 완료.
#   [EMERALD IV] 82페이지 수집 완료 (66명)
#   -> 83페이지 결과 없음. EMERALD IV 종료.
#
# ===== 시작: DIAMOND I =====
#   -> 205개 데이터 저장 완료.
#   [DIAMOND I] 1페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND I] 2페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND I] 3페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND I] 4페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND I] 5페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND I] 6페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND I] 7페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND I] 8페이지 수집 완료 (205명)
#   -> 33개 데이터 저장 완료.
#   [DIAMOND I] 9페이지 수집 완료 (33명)
#   -> 10페이지 결과 없음. DIAMOND I 종료.
#
# ===== 시작: DIAMOND II =====
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 1페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 2페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 3페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 4페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 5페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 6페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 7페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 8페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 9페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 10페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 11페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 12페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND II] 13페이지 수집 완료 (205명)
#   -> 201개 데이터 저장 완료.
#   [DIAMOND II] 14페이지 수집 완료 (201명)
#   -> 1개 데이터 저장 완료.
#   [DIAMOND II] 15페이지 수집 완료 (1명)
#   -> 16페이지 결과 없음. DIAMOND II 종료.
#
# ===== 시작: DIAMOND III =====
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 1페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 2페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 3페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 4페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 5페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 6페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 7페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 8페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 9페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 10페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 11페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 12페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 13페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 14페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 15페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 16페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 17페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 18페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 19페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND III] 20페이지 수집 완료 (205명)
#   -> 108개 데이터 저장 완료.
#   [DIAMOND III] 21페이지 수집 완료 (108명)
#   -> 22페이지 결과 없음. DIAMOND III 종료.
#
# ===== 시작: DIAMOND IV =====
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 1페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 2페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 3페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 4페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 5페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 6페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 7페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 8페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 9페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 10페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 11페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 12페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 13페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 14페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 15페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 16페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 17페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 18페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 19페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 20페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 21페이지 수집 완료 (205명)
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
# Warning: 429 에러 발생. 5초 대기 후 리트.
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 22페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 23페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 24페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 25페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 26페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 27페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 28페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 29페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 30페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 31페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 32페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 33페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 34페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 35페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 36페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 37페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 38페이지 수집 완료 (205명)
#   -> 205개 데이터 저장 완료.
#   [DIAMOND IV] 39페이지 수집 완료 (205명)
#   -> 16개 데이터 저장 완료.
#   [DIAMOND IV] 40페이지 수집 완료 (16명)
#   -> 41페이지 결과 없음. DIAMOND IV 종료.
#
# vn2서버. 405107명의 PUUID가 저장되었습니다.

# %%
for platform in platforms:
    collect_high_tier_data(platform)
# Out:
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 10000명 저장 시작.
#   -> 10000명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 700명 저장 시작.
#   -> 700명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 300명 저장 시작.
#   -> 300명 저장 완료.
#
# 작업 완료. kr서버. 파일명: data/01_puuids/kr_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 5158명 저장 시작.
#   -> 5158명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 500명 저장 시작.
#   -> 500명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 200명 저장 시작.
#   -> 200명 저장 완료.
#
# 작업 완료. br1서버. 파일명: data/01_puuids/br1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 6771명 저장 시작.
#   -> 6771명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 500명 저장 시작.
#   -> 500명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 200명 저장 시작.
#   -> 200명 저장 완료.
#
# 작업 완료. eun1서버. 파일명: data/01_puuids/eun1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 10000명 저장 시작.
#   -> 10000명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 700명 저장 시작.
#   -> 700명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 300명 저장 시작.
#   -> 300명 저장 완료.
#
# 작업 완료. euw1서버. 파일명: data/01_puuids/euw1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 1017명 저장 시작.
#   -> 1017명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 100명 저장 시작.
#   -> 100명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 50명 저장 시작.
#   -> 50명 저장 완료.
#
# 작업 완료. jp1서버. 파일명: data/01_puuids/jp1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 2500명 저장 시작.
#   -> 2500명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 500명 저장 시작.
#   -> 500명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 200명 저장 시작.
#   -> 200명 저장 완료.
#
# 작업 완료. la1서버. 파일명: data/01_puuids/la1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 2773명 저장 시작.
#   -> 2773명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 500명 저장 시작.
#   -> 500명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 200명 저장 시작.
#   -> 200명 저장 완료.
#
# 작업 완료. la2서버. 파일명: data/01_puuids/la2_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 118명 저장 시작.
#   -> 118명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 50명 저장 시작.
#   -> 50명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 45명 저장 시작.
#   -> 45명 저장 완료.
#
# 작업 완료. me1서버. 파일명: data/01_puuids/me1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 6199명 저장 시작.
#   -> 6199명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 700명 저장 시작.
#   -> 700명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 300명 저장 시작.
#   -> 300명 저장 완료.
#
# 작업 완료. na1서버. 파일명: data/01_puuids/na1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 641명 저장 시작.
#   -> 641명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 100명 저장 시작.
#   -> 100명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 50명 저장 시작.
#   -> 50명 저장 완료.
#
# 작업 완료. oc1서버. 파일명: data/01_puuids/oc1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 552명 저장 시작.
#   -> 552명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 100명 저장 시작.
#   -> 100명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 50명 저장 시작.
#   -> 50명 저장 완료.
#
# 작업 완료. ru서버. 파일명: data/01_puuids/ru_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 642명 저장 시작.
#   -> 642명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 372명 저장 시작.
#   -> 372명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 289명 저장 시작.
#   -> 289명 저장 완료.
#
# 작업 완료. sg2서버. 파일명: data/01_puuids/sg2_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 2832명 저장 시작.
#   -> 2832명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 500명 저장 시작.
#   -> 500명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 200명 저장 시작.
#   -> 200명 저장 완료.
#
# 작업 완료. tr1서버. 파일명: data/01_puuids/tr1_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 500명 저장 시작.
#   -> 500명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 314명 저장 시작.
#   -> 314명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 200명 저장 시작.
#   -> 200명 저장 완료.
#
# 작업 완료. tw2서버. 파일명: data/01_puuids/tw2_puuids_high_tiers.csv
# --- masterleagues 데이터 요청 중... ---
#   -> MASTER 응답 완료. 5205명 저장 시작.
#   -> 5205명 저장 완료.
# --- grandmasterleagues 데이터 요청 중... ---
#   -> GRANDMASTER 응답 완료. 700명 저장 시작.
#   -> 700명 저장 완료.
# --- challengerleagues 데이터 요청 중... ---
#   -> CHALLENGER 응답 완료. 300명 저장 시작.
#   -> 300명 저장 완료.
#
# 작업 완료. vn2서버. 파일명: data/01_puuids/vn2_puuids_high_tiers.csv

# %% [markdown]
# ## 확인용
